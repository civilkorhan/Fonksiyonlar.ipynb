# %%
#Tuple
a=(1,2,2,2,3,4,5)
type(a)
a.count(2)
a.index(3)
help(a)
b=()
b
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      MonthDayNano
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
a=(1, 2, 3, 4, 5, 6)
a[3]
# Out:
# 4

# %%
a=(1, 2, 3, 4, 5, 6)
a.index(3)
# Out:
# 2

# %%
# Tuple parantezle çalışır
# - değer verince tersten gelir.
a=(1, 2, 3, 4, 5, 6, 7)
a[-2]
# Out:
# 6

# %%
#listelerde sonradan atama yapılabilir indexte değişiklik yapılabilir.
list_exp=[1, 2, 3, 4, 5, 6]
list_exp
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_exp[0]=0
list_exp
# Out:
# [0, 2, 3, 4, 5, 6]

# %%
a={ "Python":2354,
  "c++":678,
  "c#":563
}
type(a)
# Out:
# dict

# %%
x={"ksdla":1,
   "dssd":2,"dsfs":3}
type(x)
# Out:
# dict

# %%
# set küme demektir içinde aynı değeri birden çok yazdırmaz belli standartları vardır.
# set sonradan değer at
a={1,2,3,3,4,4,5,6,7,7}
a
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
type(a)
# Out:
# set

# %%
empty_set={}
empty_set
# Out:
# {}

# %%
empty_set2=set()
empty_set2
# Out:
# set()

# %%
a
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a.add("kd")
a
# set ler mutable yani değiştirebilirler ekleme olabilir ama atanan değer değiştirilemez
#Kaynak:Ömer Cengiz
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'kd'}
